# %%
import topologicpy
from topologicpy.Vertex import Vertex
from topologicpy.Cell import Cell
from topologicpy.Topology import Topology
from topologicpy.Wire import Wire
from topologicpy.Face import Face

v1 = Vertex.ByCoordinates(0, 0, 0)
v2 = Vertex.ByCoordinates(-1, 2, 0)
v3 = Vertex.ByCoordinates(-1, 4, 0)
v4 = Vertex.ByCoordinates(1, 5, 0)
v5 = Vertex.ByCoordinates(0, 3, 0)

f = Face.ByVertices([v1, v2])

Topology.Show(
    f,
    #xAxis=True, yAxis=True, zAxis=True,
    showVertexLabel=True,
    showEdgeLabel=True,
    vertexSize=7,
    axisSize=5,
    projection="orthographic",
)
# Out:
# Face.ByVertices - Error: The input vertices parameter does not contain at least three valid vertices. Returning None.
# Topology.Show - Error: the input topologies parameter does not contain any valid topology. Returning None.
